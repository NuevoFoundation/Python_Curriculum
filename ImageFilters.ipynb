# %% [markdown]
# # Image Filters
#
# In this activity we are going to create cool image filters like Instagram.
#
# 1. Convert an image to black and white
# 2. (filter 2)
# 3. (filter 3)
#
# They Python Image Library (PIL) will help us build our filters.

# %%
# Indicate that we want to use the PIL library
from PIL import Image

# %% [markdown]
# ## Kitty picture
# We will be adding a filter to a cute picture of a cat.
#
#
# This is what the kitty looks like:

# %%
# With the Image.open() function we can view our kitty image.
Image.open('images/cat.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x355 at 0x1CD83A4F940>

# %%
def black_and_white(input_image_path,
    output_image_path):
    color_image = Image.open(input_image_path)
    bw = color_image.convert('L')
    bw.save(output_image_path)

# %%
black_and_white('images/cat.jpg', 'bw_cat.jpg')

# %% [markdown]
# ### Black and white kitty
# Using the PIL library, let's write a function that turns our orange kitty to black and white.

# %%
def black_and_white(original_image,
    bw_image):
    # Open the original image using Image.open() just like we did earlier
    # save it into color_image
    # color_image = 
      
    color_image = Image.open(original_image)
    bw = color_image.convert('L')
    bw.save(bw_image)

# %%
Image.open('bw_cat.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=474x355 at 0x1CD83A28BA8>
